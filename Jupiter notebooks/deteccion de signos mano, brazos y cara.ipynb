# %%
#!pip install mediapipe opencv-python pandas scikit-learn

# %%
import mediapipe as mp
import cv2
from mediapipe.python.solutions.face_mesh_connections import FACEMESH_CONTOURS

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
# DETECCIONES

# %%
cap = cv2.VideoCapture(0)   # DEFINIR CAMARA WEB A UTILIZAR

# Inicializar modelo holistic

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # CAMBIAR DE COLOR DE BGR  A  RGB
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # HACER DETECCIONES
        
        results = holistic.process(image)
        
        
        
        # CAMBIAR COLOR A BGR PARA RENDERIZAR
        
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. DIBUJAR LINEAS CARA
        mp_drawing.draw_landmarks(image, results.face_landmarks,FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. MANO DERECHA
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. MANO IZQUIERDA
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. DETECCION CUERPO
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %%
#CAPTURAR LANDMARKS Y EXPORTAR A CSV

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
    
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
# GRABA UN CSV EN LA CARPETA DIRECTORIO JUPYTER

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
# de aqui para abajo, nombre de clase con lo que queremos que haga, feliz,triste,etc..
# de momento " wakanda Forever"

# %%
class_name = "hombre"

# %%
# CREAR CSV DEL MOVIMIENTO SENTIR, GRABANDO MOVIMIENTOS CON CAMARA 

cap = cv2.VideoCapture(0)

# INIZIALIZAR MODELO HOLISTICO

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # CAMBIAR DE COLOR BGR A RGB
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # HACER DETECCIONES
        
        results = holistic.process(image)
       
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        
        # CAMBIAR DE RGB A BGR PARA RENDERIZAR 
        
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. DIBUJAR LANDMARKS DE CARA
        mp_drawing.draw_landmarks(image, results.face_landmarks,FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. DIBUJAR LANDMARKS DE MANO DERECHA
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. DIBUJAR LANDMARKS DE MANO IZQUIERDA
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. DIBUJAR LANDMARKS DE CUERPO
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extraer cuerpo (pose_landmarks) 
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extraer cara (face_landmarks)
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
             # Extraer mano derecha landmarks(right_hand_landmarks)
            handr = results.right_hand_landmarks.landmark
            handr_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handr]).flatten())
            
            
            # Extraer mano izquierda landmarks(left_hand_landmarks)
            handl = results.left_hand_landmarks.landmark
            handl_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handl]).flatten())
            
            
            
            # Concate rows ( UNIR ROWS)
            row = pose_row+face_row+handr_row+handl_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
# ----------MACHINE LEARNING----------------------

# %%
# 3.1 TRAIN/TEST

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#    sentir  0.45307883620262146  0.29737967252731323  -0.5939964056015015  \
# 0  sentir             0.459995             0.298973            -0.557158
# 1  sentir             0.468407             0.300642            -0.574842
# 2  sentir             0.473260             0.300292            -0.561040
# 3  sentir             0.475184             0.300473            -0.541105
# 4  sentir             0.480271             0.300934            -0.542221
#
#    0.9998180270195007  0.4698456823825836  0.266276478767395  \
# 0            0.999803            0.472755           0.267019
# 1            0.999762            0.479384           0.267141
# 2            0.999745            0.483091           0.266271
# 3            0.999722            0.485092           0.266229
# 4            0.999716            0.489355           0.266311
#
#    -0.5561590194702148  0.9995706677436829  0.47876864671707153  ...  \
# 0            -0.517565            0.999557             0.481759  ...
# 1            -0.534651            0.999488             0.487932  ...
# 2            -0.519880            0.999472             0.491168  ...
# 3            -0.502011            0.999442             0.492981  ...
# 4            -0.502799            0.999442             0.496767  ...
#
#    -0.02149175852537155.1  0.0.507  0.37245696783065796.1  \
# 0               -0.024085      0.0               0.376985
# 1               -0.024848      0.0               0.386031
# 2               -0.024402      0.0               0.392911
# 3               -0.023807      0.0               0.398383
# 4               -0.023076      0.0               0.402971
# 133            0.999682            0.509045           0.231272
# 134            0.999670            0.509045           0.233374
# 135            0.999671            0.504511           0.237595
# 136            0.999667            0.500155           0.239027
# 137            0.999646            0.492061           0.241422
# ..                  ...                 ...                ...
# 325            0.998295            0.587544           0.221772
# 326            0.998455            0.617948           0.230510
# 327            0.998905            0.767600           0.346057
# 328            0.998980            0.792322           0.366498
# 329            0.999040            0.805209           0.386526
#
#      -0.5561590194702148  0.9995706677436829  0.47876864671707153  ...  \
# 133            -0.627618            0.999463             0.517462  ...
# 134            -0.515102            0.999430             0.517408  ...
# 135            -0.523579            0.999427             0.513243  ...
# 136            -0.522958            0.999413             0.509225  ...
# 137            -0.535357            0.999367             0.501497  ...
# ..                   ...                 ...                  ...  ...
# 325            -0.709448            0.996807             0.596588  ...
# 326            -0.724148            0.997101             0.625771  ...
# 327            -0.677916            0.997929             0.769790  ...
# 328            -0.669003            0.998045             0.793494  ...
# 329            -0.755920            0.998117             0.808953  ...
#
#      -0.02149175852537155.1  0.0.507  0.37245696783065796.1  \
# 133               -0.031709      0.0               0.473390
# 134               -0.030432      0.0               0.471786
# 135               -0.029898      0.0               0.472710
# 136               -0.033159      0.0               0.472765
# 137               -0.031503      0.0               0.468533
# ..                      ...      ...                    ...
# 325               -0.006280      0.0               0.573998
# 326               -0.022015      0.0               0.585199
# 327               -0.032309      0.0               0.559861
# 328               -0.024008      0.0               0.545619
# 329               -0.015916      0.0               0.548537
#
#      0.9924506545066833.1  -0.01714133657515049.1  0.0.508  \
# 133              0.827545               -0.024438      0.0
# 134              0.803971               -0.023096      0.0
# 135              0.781648               -0.023145      0.0
# 136              0.766263               -0.024856      0.0
# 137              0.755291               -0.024485      0.0
# ..                    ...                     ...      ...
# 325              0.457364               -0.000999      0.0
# 326              0.498815               -0.016440      0.0
# 327              0.913686               -0.031081      0.0
# 328              0.950042               -0.026289      0.0
# 329              0.946868               -0.019535      0.0
#
#      0.3638998568058014.1  0.9827441573143005.1  -0.013218957930803299.1  \
# 133              0.478605              0.817569                -0.016897
# 134              0.474983              0.795345                -0.015901
# 135              0.475023              0.773405                -0.016521
# 136              0.475810              0.756181                -0.017007
# 137              0.474942              0.746192                -0.017881
# ..                    ...                   ...                      ...
# 325              0.566694              0.453015                 0.003009
# 326              0.578011              0.493257                -0.011662
# 327              0.571245              0.896666                -0.026049
# 328              0.560515              0.937908                -0.025615
# 329              0.564851              0.932266                -0.020000
#
#      0.0.509
# 133      0.0
# 134      0.0
# 135      0.0
# 136      0.0
# 137      0.0
# ..       ...
# 325      0.0
# 326      0.0
# 327      0.0
# 328      0.0
# 329      0.0
#
# [197 rows x 2173 columns]

# %%
X = df.drop('sentir', axis=1) # features
y = df['sentir'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 137    colegio
# 7       sentir
# 321    colegio
# 185    colegio
# 265    colegio
#         ...
# 179    colegio
# 118     sentir
# 122     sentir
# 296    colegio
# 131     sentir
# Name: sentir, Length: 99, dtype: object

# %%
# 3.2 ENTRENAR TRAIN/TEST --- PREDICIR

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(MinMaxScaler(), LogisticRegression()),
    'rc':make_pipeline(MinMaxScaler(), RidgeClassifier()),
    'rf':make_pipeline(MinMaxScaler(), RandomForestClassifier()),
    'gb':make_pipeline(MinMaxScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\Jose Antonio Amador\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['lr'].predict(X_test)
# Out:
# array(['colegio', 'sentir', 'colegio', 'colegio', 'colegio', 'sentir',
#        'colegio', 'colegio', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'sentir', 'colegio',
#        'colegio', 'colegio', 'sentir', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'sentir', 'sentir', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'colegio', 'colegio', 'sentir',
#        'sentir', 'colegio', 'sentir'], dtype=object)

# %%
# 3.3 EVALUAR Y SERIALIZAR MODELO

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 0.98989898989899
# gb 1.0

# %%
#ELEGIMOS RF YA QUE TODOS DAN LA MISMA PRECISION

fit_models['lr'].predict(X_test)
# Out:
# array(['colegio', 'sentir', 'colegio', 'colegio', 'colegio', 'sentir',
#        'colegio', 'colegio', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'sentir', 'colegio',
#        'colegio', 'colegio', 'sentir', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'sentir', 'sentir', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'colegio', 'colegio', 'sentir',
#        'sentir', 'colegio', 'sentir'], dtype=object)

# %%
y_test
# Out:
# 40      sentir
# 44      sentir
# 358     hombre
# 59      sentir
# 349     hombre
#         ...
# 333     hombre
# 133    colegio
# 264     hombre
# 389     hombre
# 42      sentir
# Name: sentir, Length: 120, dtype: object

# %%
# CREA UN ARCHIVO BODY_LANGUAGE.PKL DONDE ALMACENA EL TRAIN

with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['lr'], f)

# %%
# 4. HACER DETECCIONES CON EL MODELO

# %%
# CARGA  EL ARCHIVO PARA UTILIZAR EL INTERIOR

with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. DIBUJAR LANDMARKS DE CARA
        mp_drawing.draw_landmarks(image, results.face_landmarks,FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. DIBUJAR LANDMARKS DE MANO DERECHA
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. DIBUJAR LANDMARKS DE MANO IZQUIERDA
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. DIBUJAR LANDMARKS DE CUERPO
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extraer cuerpo (pose_landmarks) 
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extraer cara (face_landmarks)
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
             # Extraer mano derecha landmarks(right_hand_landmarks)
            handr = results.right_hand_landmarks.landmark
            handr_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handr]).flatten())
            
            
            # Extraer mano izquierda landmarks(left_hand_landmarks)
            handl = results.left_hand_landmarks.landmark
            handl_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handl]).flatten())
            
            
            
            # Concate rows ( UNIR ROWS)
            row = pose_row+face_row+handr_row+handl_row
            
        
                   
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

         
    
            # HACER DETECCIONES
        
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            
            # esto escribe la precision de la palabra
            
            print(body_language_class, body_language_prob)
            
            
            # Grab ear coords
            #puntos de referencia para mejorar la prediccion( aqui las orejas) 
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            #RECTANGULO
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            
            #TEXTO DENTRO RECTANGULO
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (479, 320)
