# %%
#!pip install mediapipe opencv-python pandas scikit-learn

# %%
import mediapipe as mp
import cv2
from mediapipe.python.solutions.face_mesh_connections import FACEMESH_CONTOURS

# %%
mp_drawing = mp.solutions.drawing_utils 
mp_holistic = mp.solutions.holistic

# %% [markdown]
# # DETECCIONES

# %%
#cap = cv2.VideoCapture('./reconocimiento_imagenes/DATA/colegio 6.mp4')   
cap = cv2.VideoCapture('./word-colegio-006.mp4')   

with mp_holistic.Holistic(static_image_mode=True,model_complexity=2) as holistic:

     while True:
          ret, frame = cap.read()
          if ret == False:
               break

          frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
          results = holistic.process(frame_rgb)

           # CARA
          mp_drawing.draw_landmarks(
               frame_rgb, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
               mp_drawing.DrawingSpec(color=(0, 255, 255), thickness=1, circle_radius=1),
               mp_drawing.DrawingSpec(color=(0, 128, 255), thickness=2))
          
          # Mano izquieda (azul)
          mp_drawing.draw_landmarks(
               frame_rgb, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
               mp_drawing.DrawingSpec(color=(255, 255, 0), thickness=2, circle_radius=1),
               mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=2))
          
          # Mano derecha (verde)
          mp_drawing.draw_landmarks(
               frame_rgb, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
               mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=1),
               mp_drawing.DrawingSpec(color=(57, 143, 0), thickness=2))
          
          # Postura
          mp_drawing.draw_landmarks(
               frame_rgb, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
               mp_drawing.DrawingSpec(color=(128, 0, 255), thickness=2, circle_radius=1),
               mp_drawing.DrawingSpec(color=(255, 255, 255), thickness=2))

          #frame = cv2.flip(frame,1) #para voltearlo como un selfie
          cv2.imshow("Imagen a detectar", frame_rgb)
          if (cv2.waitKey(1) & 0xFF == ('s')):
               break
            

cap.release()
cv2.destroyAllWindows()

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %%
results.right_hand_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # CAPTURAR LANDMARKS Y EXPORTAR A CSV

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)+len(results.right_hand_landmarks.landmark)
num_coords
# Out:
# 522

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]
    
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
# GRABA UN CSV EN LA CARPETA DIRECTORIO JUPYTER

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %% [markdown]
# Aqui nombre de como quieres que se llama la clase que creas con las coordenadas , en este momento " colegio "

# %%
class_name = "colegio"

# %%
# CREAR CSV DEL MOVIMIENTO SENTIR, GRABANDO MOVIMIENTOS CON CAMARA 

rows = []
rows.append(landmarks)

# INIZIALIZAR MODELO HOLISTICO
for i in range(1, 6):
     cap = cv2.VideoCapture("word-colegio-{}.mp4".format(str(i).zfill(3)))  
     with mp_holistic.Holistic(static_image_mode=True,model_complexity=2) as holistic: 

          while True:
               ret, frame = cap.read()
               if ret == False:
                    break

               frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
               results = holistic.process(frame_rgb)

               # CARA
               mp_drawing.draw_landmarks(
                    frame_rgb, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                    mp_drawing.DrawingSpec(color=(0, 255, 255), thickness=1, circle_radius=1),
                    mp_drawing.DrawingSpec(color=(0, 128, 255), thickness=2))
               
               # Mano izquieda (azul)
               mp_drawing.draw_landmarks(
                    frame_rgb, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(255, 255, 0), thickness=2, circle_radius=1),
                    mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=2))
               
               # Mano derecha (verde)
               mp_drawing.draw_landmarks(
                    frame_rgb, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=1),
                    mp_drawing.DrawingSpec(color=(57, 143, 0), thickness=2))
               
               # Postura
               mp_drawing.draw_landmarks(
                    frame_rgb, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(128, 0, 255), thickness=2, circle_radius=1),
                    mp_drawing.DrawingSpec(color=(255, 255, 255), thickness=2))

          
               
          # Export coordinates
               try:
                    # Extraer cuerpo (pose_landmarks) 
                    pose = results.pose_landmarks.landmark
                    pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
               
                    # Extraer cara (face_landmarks)
                    face = results.face_landmarks.landmark
                    face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
               
                    # Extraer mano derecha landmarks(right_hand_landmarks)
                    handr = results.right_hand_landmarks.landmark
                    handr_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handr]).flatten())
               
               
                    # Extraer mano izquierda landmarks(left_hand_landmarks)
                    #handl = results.left_hand_landmarks.landmark
                    #handl_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handl]).flatten())
               
               
               
                    # Concate rows ( UNIR ROWS)
                    
                    row = pose_row + face_row + handr_row 
               
                    # Append class name 
                    row.insert(0, class_name)

                    rows.append(row)
               
                    
               
               except:
                    pass
               #frame = cv2.flip(frame,1) #para voltear la imagen en caso de selfie
               ##cv2.imshow("Imagen a detectar", frame_rgb)
          
               if (cv2.waitKey(1) & 0xFF == ('s')):
                    break                

# Export to CSV
with open('coords.csv', mode='a', newline='') as f:
     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
     csv_writer.writerow(rows) 

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
#   TRAIN/TEST

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 0  colegio  0.542448  0.287493 -0.450632  0.993115  0.549810  0.239985
# 1  colegio  0.541501  0.286805 -0.447421  0.994012  0.549700  0.238217
# 2  colegio  0.539424  0.275740 -0.431652  0.998568  0.546558  0.229591
# 3  colegio  0.531044  0.262895 -0.373957  0.996363  0.538306  0.222062
# 4  colegio  0.527713  0.259538 -0.280764  0.994459  0.532085  0.215187
#
#          z2        v2        x3  ...      z520  v520      x521      y521  \
# 0 -0.423480  0.977369  0.557857  ... -0.027578   0.0  0.487728  0.362484
# 1 -0.419311  0.980266  0.557904  ... -0.024927   0.0  0.488263  0.363901
# 2 -0.408555  0.994948  0.553792  ... -0.032038   0.0  0.506287  0.323541
# 3 -0.351374  0.988592  0.546002  ... -0.029905   0.0  0.527492  0.315024
# 4 -0.252039  0.987651  0.539559  ... -0.025342   0.0  0.541892  0.323577
#
#        z521  v521      x522      y522      z522  v522
# 0 -0.026790   0.0  0.496328  0.341664 -0.026061   0.0
# 1 -0.023565   0.0  0.496995  0.344405 -0.022159   0.0
# 2 -0.031856   0.0  0.515870  0.300872 -0.031212   0.0
# 3 -0.028473   0.0  0.537169  0.294638 -0.026984   0.0
# 4 -0.023300   0.0  0.550011  0.305239 -0.021472   0.0
#
# [5 rows x 2089 columns]

# %%
df.tail()
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 24  colegio  0.425628  0.283235 -0.441155  0.986950  0.441154  0.233881
# 25  colegio  0.419673  0.269750 -0.379036  0.995173  0.434416  0.228495
# 26  colegio  0.421486  0.268388 -0.408138  0.995743  0.436125  0.227469
# 27  colegio  0.420117  0.264299 -0.402289  0.998279  0.436747  0.222179
# 28  colegio  0.431896  0.263297 -0.394978  0.993218  0.446088  0.221484
#
#           z2        v2        x3  ...      z520  v520      x521      y521  \
# 24 -0.417167  0.953471  0.453416  ... -0.029633   0.0  0.421491  0.409680
# 25 -0.357044  0.982852  0.443773  ... -0.029550   0.0  0.417911  0.383050
# 26 -0.390855  0.983911  0.445198  ... -0.030152   0.0  0.419756  0.369506
# 27 -0.382308  0.994152  0.446582  ... -0.027517   0.0  0.428527  0.359796
# 28 -0.376032  0.976091  0.456386  ... -0.026988   0.0  0.439594  0.363603
#
#         z521  v521      x522      y522      z522  v522
# 24 -0.029331   0.0  0.432650  0.392885 -0.028751   0.0
# 25 -0.029260   0.0  0.429057  0.364414 -0.028588   0.0
# 26 -0.029381   0.0  0.431313  0.351660 -0.028491   0.0
# 27 -0.026724   0.0  0.439274  0.342597 -0.025682   0.0
# 28 -0.026365   0.0  0.451236  0.347373 -0.025471   0.0
#
# [5 rows x 2089 columns]

# %%
df[df['class']=='colegio']
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0   colegio  0.542448  0.287493 -0.450632  0.993115  0.549810  0.239985
# 1   colegio  0.541501  0.286805 -0.447421  0.994012  0.549700  0.238217
# 2   colegio  0.539424  0.275740 -0.431652  0.998568  0.546558  0.229591
# 3   colegio  0.531044  0.262895 -0.373957  0.996363  0.538306  0.222062
# 4   colegio  0.527713  0.259538 -0.280764  0.994459  0.532085  0.215187
# 5   colegio  0.523002  0.264403 -0.313236  0.998945  0.528907  0.220380
# 6   colegio  0.526524  0.262071 -0.289230  0.997103  0.530672  0.217569
# 7   colegio  0.521579  0.265404 -0.310208  0.998395  0.527165  0.222177
# 8   colegio  0.517896  0.273615 -0.303261  0.999433  0.523641  0.228812
# 9   colegio  0.514825  0.273544 -0.308347  0.999273  0.519702  0.228758
# 10  colegio  0.506486  0.271557 -0.337878  0.998920  0.512600  0.225933
# 11  colegio  0.497440  0.274725 -0.357674  0.997522  0.503282  0.227919
# 12  colegio  0.484536  0.278245 -0.350555  0.996978  0.491786  0.231465
# 13  colegio  0.470509  0.273861 -0.400667  0.997621  0.482542  0.228467
# 14  colegio  0.465674  0.275759 -0.394831  0.995568  0.474409  0.228983
# 15  colegio  0.455268  0.268263 -0.346043  0.996008  0.467062  0.222912
# 16  colegio  0.448308  0.265478 -0.430996  0.997106  0.461107  0.221648
# 17  colegio  0.444887  0.260695 -0.387540  0.997085  0.458383  0.218461
# 18  colegio  0.439839  0.265933 -0.458444  0.997182  0.455253  0.221868
# 19  colegio  0.440616  0.271455 -0.532314  0.998196  0.456336  0.225208
# 20  colegio  0.432998  0.280865 -0.469141  0.998479  0.450075  0.230679
# 21  colegio  0.430530  0.284190 -0.469930  0.998128  0.446895  0.230831
# 22  colegio  0.429560  0.287655 -0.429336  0.997586  0.444495  0.236016
# 23  colegio  0.425953  0.287647 -0.432668  0.995418  0.440802  0.236855
# 24  colegio  0.425628  0.283235 -0.441155  0.986950  0.441154  0.233881
# 25  colegio  0.419673  0.269750 -0.379036  0.995173  0.434416  0.228495
# 26  colegio  0.421486  0.268388 -0.408138  0.995743  0.436125  0.227469
# 27  colegio  0.420117  0.264299 -0.402289  0.998279  0.436747  0.222179
# 28  colegio  0.431896  0.263297 -0.394978  0.993218  0.446088  0.221484
#
#           z2        v2        x3  ...      z520  v520      x521      y521  \
# 0  -0.423480  0.977369  0.557857  ... -0.027578   0.0  0.487728  0.362484
# 1  -0.419311  0.980266  0.557904  ... -0.024927   0.0  0.488263  0.363901
# 2  -0.408555  0.994948  0.553792  ... -0.032038   0.0  0.506287  0.323541
# 3  -0.351374  0.988592  0.546002  ... -0.029905   0.0  0.527492  0.315024
# 4  -0.252039  0.987651  0.539559  ... -0.025342   0.0  0.541892  0.323577
# 5  -0.280276  0.998464  0.537555  ... -0.026898   0.0  0.554771  0.326597
# 6  -0.258680  0.995875  0.537648  ... -0.027040   0.0  0.555954  0.346781
# 7  -0.276183  0.997656  0.533789  ... -0.027417   0.0  0.550337  0.370847
# 8  -0.267021  0.999233  0.531502  ... -0.023771   0.0  0.542317  0.391403
# 9  -0.273580  0.999022  0.527553  ... -0.028356   0.0  0.526804  0.418767
# 10 -0.302419  0.998338  0.519637  ... -0.030997   0.0  0.513848  0.408578
# 11 -0.325417  0.995222  0.511458  ... -0.029218   0.0  0.504915  0.395566
# 12 -0.320664  0.993114  0.501017  ... -0.028266   0.0  0.493343  0.376089
# 13 -0.367965  0.994079  0.493116  ... -0.027624   0.0  0.482813  0.350648
# 14 -0.365340  0.988552  0.484155  ... -0.025807   0.0  0.480440  0.337974
# 15 -0.316356  0.991695  0.478084  ... -0.026928   0.0  0.480011  0.332374
# 16 -0.397263  0.993339  0.471191  ... -0.029737   0.0  0.483070  0.337349
# 17 -0.353256  0.994065  0.468150  ... -0.031265   0.0  0.484478  0.340240
# 18 -0.424051  0.994698  0.465235  ... -0.027190   0.0  0.479847  0.354869
# 19 -0.495211  0.996118  0.465533  ... -0.027316   0.0  0.473199  0.376713
# 20 -0.431962  0.997327  0.460556  ... -0.028073   0.0  0.465995  0.397309
# 21 -0.434038  0.996541  0.457872  ... -0.029775   0.0  0.454269  0.415166
# 22 -0.398356  0.994790  0.455781  ... -0.028893   0.0  0.442885  0.420620
# 23 -0.404997  0.988767  0.452653  ... -0.027489   0.0  0.433063  0.415383
# 24 -0.417167  0.953471  0.453416  ... -0.029633   0.0  0.421491  0.409680
# 25 -0.357044  0.982852  0.443773  ... -0.029550   0.0  0.417911  0.383050
# 26 -0.390855  0.983911  0.445198  ... -0.030152   0.0  0.419756  0.369506
# 27 -0.382308  0.994152  0.446582  ... -0.027517   0.0  0.428527  0.359796
# 28 -0.376032  0.976091  0.456386  ... -0.026988   0.0  0.439594  0.363603
#
#         z521  v521      x522      y522      z522  v522
# 0  -0.026790   0.0  0.496328  0.341664 -0.026061   0.0
# 1  -0.023565   0.0  0.496995  0.344405 -0.022159   0.0
# 2  -0.031856   0.0  0.515870  0.300872 -0.031212   0.0
# 3  -0.028473   0.0  0.537169  0.294638 -0.026984   0.0
# 4  -0.023300   0.0  0.550011  0.305239 -0.021472   0.0
# 5  -0.024258   0.0  0.560210  0.306504 -0.021501   0.0
# 6  -0.023512   0.0  0.562682  0.326578 -0.020153   0.0
# 7  -0.025190   0.0  0.557767  0.350664 -0.022676   0.0
# 8  -0.021789   0.0  0.550153  0.371541 -0.019591   0.0
# 9  -0.027439   0.0  0.534635  0.399521 -0.026084   0.0
# 10 -0.030386   0.0  0.524306  0.388919 -0.029286   0.0
# 11 -0.028034   0.0  0.516316  0.378176 -0.026776   0.0
# 12 -0.027002   0.0  0.504365  0.358242 -0.025635   0.0
# 13 -0.026375   0.0  0.493955  0.332602 -0.025118   0.0
# 14 -0.023669   0.0  0.490138  0.320551 -0.021562   0.0
# 15 -0.024926   0.0  0.489982  0.315003 -0.022809   0.0
# 16 -0.028310   0.0  0.493512  0.319919 -0.026722   0.0
# 17 -0.030673   0.0  0.494858  0.320514 -0.029701   0.0
# 18 -0.025515   0.0  0.489078  0.336730 -0.023746   0.0
# 19 -0.025395   0.0  0.482989  0.359043 -0.023410   0.0
# 20 -0.026553   0.0  0.476064  0.379035 -0.024828   0.0
# 21 -0.028344   0.0  0.464377  0.396328 -0.026676   0.0
# 22 -0.027803   0.0  0.453382  0.403141 -0.026491   0.0
# 23 -0.026612   0.0  0.443550  0.396648 -0.025445   0.0
# 24 -0.029331   0.0  0.432650  0.392885 -0.028751   0.0
# 25 -0.029260   0.0  0.429057  0.364414 -0.028588   0.0
# 26 -0.029381   0.0  0.431313  0.351660 -0.028491   0.0
# 27 -0.026724   0.0  0.439274  0.342597 -0.025682   0.0
# 28 -0.026365   0.0  0.451236  0.347373 -0.025471   0.0
#
# [29 rows x 2089 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 7     colegio
# 10    colegio
# 4     colegio
# 1     colegio
# 27    colegio
# 8     colegio
# 3     colegio
# 14    colegio
# 13    colegio
# Name: class, dtype: object

# %% [markdown]
# ENTRENAR TRAIN/TEST --- PREDICIR

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(MinMaxScaler(), LogisticRegression()),
    'rc':make_pipeline(MinMaxScaler(), RidgeClassifier()),
    'rf':make_pipeline(MinMaxScaler(), RandomForestClassifier()),
    'gb':make_pipeline(MinMaxScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\Jose Antonio Amador\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['lr'].predict(X_test)
# Out:
# array(['colegio', 'sentir', 'colegio', 'colegio', 'colegio', 'sentir',
#        'colegio', 'colegio', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'sentir', 'colegio',
#        'colegio', 'colegio', 'sentir', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'sentir', 'sentir', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'colegio', 'colegio', 'sentir',
#        'sentir', 'colegio', 'sentir'], dtype=object)

# %%
# 3.3 EVALUAR Y SERIALIZAR MODELO

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 0.98989898989899
# gb 1.0

# %%
#ELEGIMOS RF YA QUE TODOS DAN LA MISMA PRECISION

fit_models['lr'].predict(X_test)
# Out:
# array(['colegio', 'sentir', 'colegio', 'colegio', 'colegio', 'sentir',
#        'colegio', 'colegio', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'sentir', 'colegio',
#        'colegio', 'colegio', 'sentir', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'colegio', 'colegio',
#        'sentir', 'colegio', 'sentir', 'sentir', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'sentir', 'sentir', 'sentir', 'sentir', 'colegio', 'colegio',
#        'colegio', 'sentir', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'sentir', 'sentir', 'sentir',
#        'colegio', 'colegio', 'colegio', 'colegio', 'sentir', 'sentir',
#        'colegio', 'sentir', 'sentir', 'colegio', 'colegio', 'sentir',
#        'sentir', 'colegio', 'sentir'], dtype=object)

# %%
y_test
# Out:
# 40      sentir
# 44      sentir
# 358     hombre
# 59      sentir
# 349     hombre
#         ...
# 333     hombre
# 133    colegio
# 264     hombre
# 389     hombre
# 42      sentir
# Name: sentir, Length: 120, dtype: object

# %%
# CREA UN ARCHIVO BODY_LANGUAGE.PKL DONDE ALMACENA EL TRAIN

with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['lr'], f)

# %%
# 4. HACER DETECCIONES CON EL MODELO

# %%
# CARGA  EL ARCHIVO PARA UTILIZAR EL INTERIOR

with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. DIBUJAR LANDMARKS DE CARA
        mp_drawing.draw_landmarks(image, results.face_landmarks,FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. DIBUJAR LANDMARKS DE MANO DERECHA
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. DIBUJAR LANDMARKS DE MANO IZQUIERDA
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. DIBUJAR LANDMARKS DE CUERPO
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Export coordinates
        try:
            # Extraer cuerpo (pose_landmarks) 
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extraer cara (face_landmarks)
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
             # Extraer mano derecha landmarks(right_hand_landmarks)
            handr = results.right_hand_landmarks.landmark
            handr_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handr]).flatten())
            
            
            # Extraer mano izquierda landmarks(left_hand_landmarks)
            handl = results.left_hand_landmarks.landmark
            handl_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in handl]).flatten())
            
            
            
            # Concate rows ( UNIR ROWS)
            row = pose_row+face_row+handr_row+handl_row
            
        
                   
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

         
    
            # HACER DETECCIONES
        
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            
            # esto escribe la precision de la palabra
            
            print(body_language_class, body_language_prob)
            
            
            # Grab ear coords
            #puntos de referencia para mejorar la prediccion( aqui las orejas) 
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            #RECTANGULO
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            
            #TEXTO DENTRO RECTANGULO
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (479, 320)
